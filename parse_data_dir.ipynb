# %% [markdown]
# ## Fellows

# %%
import re
import yaml
import json

import glob
import os
    
from tqdm import tqdm  

from pprint import pprint   

from pathlib import Path
data_dir ="../interim-bdc-website/src/data/"

fellow_dir = Path(data_dir + "fellows/").resolve()

def parse_fellow_file(file_path):
    """Parse a single fellow markdown file and return the data as a dictionary."""
    try:
        with open(file_path, 'r', encoding='utf-8') as f:
            content = f.read().strip()
            # Remove YAML delimiters
            yaml_content = content.replace('---\n', '', 1)  # Remove first delimiter
            yaml_content = yaml_content.rsplit('---', 1)[0]  # Remove last delimiter
            
            fellow_data = yaml.safe_load(yaml_content)
            fellow_data["file_path"] = file_path
            return fellow_data
    except yaml.YAMLError as e:
        print(f"Error parsing {file_path}: {e}")
        return None

def get_fellows(fellow_dir):
    fellows = []
    # Get all .md files in the directory
    md_files = glob.glob(os.path.join(fellow_dir, "*.md"))
    
    for file_path in tqdm(md_files, desc="Reading fellow files"):
        fellow_data = parse_fellow_file(file_path)
        if fellow_data:
            fellows.append(fellow_data)
                
    return fellows

fellows = get_fellows(fellow_dir)
# Out:
# Reading fellow files: 100%|██████████| 47/47 [00:00<00:00, 821.02it/s]

# %%
for i, fellow in enumerate(fellows):
    print(f"{i+1}: {json.dumps(fellow, indent=2)}\n")

# %% [markdown]
# ## Latest Updates

# %%
updates_dir = data_dir + "latest-updates/"

# %%
def parse_mdx_file(file_path):
    """Parse a MDX file with YAML frontmatter and markdown content.
    
    Args:
        file_path (str): Path to the MDX file
        
    Returns:
        tuple: (metadata_dict, markdown_content)
            - metadata_dict: Dictionary containing the YAML frontmatter data
            - markdown_content: String containing the markdown content
    """
    try:
        with open(file_path, 'r', encoding='utf-8') as f:
            content = f.read().strip()
            
        # Split content into YAML and markdown parts
        parts = content.split('---\n', 2)
        if len(parts) < 3:
            raise ValueError("File does not contain valid YAML frontmatter")
            
        # Parse YAML header (middle part between --- delimiters)
        metadata = yaml.safe_load(parts[1])
        
        # Get markdown content (everything after second ---)
        markdown_content = parts[2].strip()
        
        # Add file path to metadata
        metadata['file_path'] = file_path
        
        return metadata, markdown_content
        
    except (yaml.YAMLError, ValueError) as e:
        print(f"Error parsing {file_path}: {e}")
        return None, None

metadata, content = parse_mdx_file('C:/!Work/interim-bdc-website/src/data/latest-updates/2021-08-15_welcome/index.mdx')
if metadata:
    print("Metadata:", metadata)
    print("\nContent:", content)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 36
#      33         print(f"Error parsing {file_path}: {e}")
#      34         return None, None
# ---> 36 metadata, content = parse_mdx_file('C:/!Work/interim-bdc-website/src/data/latest-updates/2021-08-15_welcome/index.mdx')
#      37 if metadata:
#      38     print("Metadata:", metadata)
#
# Cell In[4], line 13, in parse_mdx_file(file_path)
#       2 """Parse a MDX file with YAML frontmatter and markdown content.
#       3
#       4 Args:
#    (...)
#      10         - markdown_content: String containing the markdown content
#      11 """
#      12 try:
# ---> 13     with open(file_path, 'r', encoding='utf-8') as f:
#      14         content = f.read().strip()
#      16     # Split content into YAML and markdown parts
#
# File ~/code/BDC_Chatbot/.venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:/!Work/interim-bdc-website/src/data/latest-updates/2021-08-15_welcome/index.mdx'

# %%
def get_mdx_files(updates_dir):
    """Get all MDX files directly under the directory and index.mdx from subdirectories.
    
    Args:
        updates_dir (str): Path to the directory containing MDX files
        
    Returns:
        tuple: (paths, metadata_list, content_list)
            - paths: List of paths to MDX files
            - metadata_list: List of metadata dictionaries
            - content_list: List of markdown content strings
    """
    paths = []
    metadata_list = []
    content_list = []
    
    # Get MDX files directly under the directory
    direct_mdx = glob.glob(os.path.join(updates_dir, "*.mdx"))
    
    # Get index.mdx files from subdirectories
    subdir_mdx = glob.glob(os.path.join(updates_dir, "**/index.mdx"))
    
    # Combine all file paths
    all_mdx_paths = direct_mdx + subdir_mdx
    
    # Parse each file
    for file_path in tqdm(all_mdx_paths, desc="Parsing MDX files"):
        metadata, content = parse_mdx_file(file_path)
        if metadata and content:  # Only add if parsing was successful
            paths.append(file_path)
            metadata_list.append(metadata)
            content_list.append(content)
    
    return paths, metadata_list, content_list

# %%
paths, metadata, contents = get_mdx_files(updates_dir)


print(f"Found {len(paths)} MDX files")


for i in range(len(paths)):
    print(f"\nFile {i+1}: {paths[i]}")
    print("Metadata:", metadata[i])
    print("Content preview:", contents[i][:100], "...")
# Out:
# Parsing MDX files: 100%|██████████| 7/7 [00:00<00:00, 294.20it/s]
# Found 7 MDX files
#
# File 1: C:/!Work/interim-bdc-website/src/data/latest-updates\2021-08-15_welcome\index.mdx
# Metadata: {'path': '/latest-updates/NHLBI-BioData-Catalyst-welcomes-all-researchers', 'date': datetime.date(2021, 7, 20), 'title': 'NHLBI BioData Catalyst welcomes all researchers', 'subtitle': 'Cloud-based ecosystem provides tools, applications, and workflows in secure workspaces for the heart, lung, blood, and sleep research community.', 'tags': ['news'], 'seo': {'title': 'NHLBI BioData Catalyst welcomes all researchers', 'description': 'Cloud-based ecosystem provides tools, applications, and workflows in secure workspaces for the heart, lung, blood, and sleep research community. ', 'keywords': ['']}, 'file_path': 'C:/!Work/interim-bdc-website/src/data/latest-updates\\2021-08-15_welcome\\index.mdx'}
# Content preview: The NHLBI BioData Catalyst announced today that its ecosystem, which has undergone rigorous pilot te ...
#
# File 2: C:/!Work/interim-bdc-website/src/data/latest-updates\2021-12-10_michelle_daya_research\index.mdx
# Metadata: {'path': '/latest-updates/michelle_daya_research', 'date': datetime.date(2021, 12, 10), 'title': 'BioData Catalyst Used for Genomics Research on Link Between Genetic Risk and Allergic Disease', 'subtitle': '', 'author': '', 'tags': ['blog', 'asthma', 'GWAS', 'HLA', 'multiethnic', 'diversity', 'allergies', 'cloud computing'], 'researcher': {'name': 'Dr. Michelle Daya', 'image': './daya-michelle.jpg', 'description': 'Michelle Daya, PhD, is a human genetics researcher, with a focus on how genetic makeup influences risk for developing common allergies such as asthma and eczema. Her research was supported in part by the BioData Catalyst Fellowship Program, which she participated in during Cohort I. For her study, Multiethnic genome-wide and HLA association study of total serum IgE level, she leveraged data from the National Heart, Lung and Blood Institute (NHLBI) Trans-Omics for Precision Medicine (TOPMed) program; the Consortium on Asthma among African-ancestry Populations in the Americas (CAAPA); and the Atopic Dermatitis Research Network (ADRN).\n'}, 'seo': {'title': 'BioData Catalyst Used for Genomics Research on Link Between Genetic Risk and Allergic Disease', 'description': '', 'keywords': ['blog', 'asthma', 'GWAS', 'HLA', 'multiethnic', 'diversity', 'allergies', 'cloud computing']}, 'file_path': 'C:/!Work/interim-bdc-website/src/data/latest-updates\\2021-12-10_michelle_daya_research\\index.mdx'}
# Content preview: Do you enjoy the smell of freshly cut grass, or do you fall victim to sneezing and an incessantly ru ...
#
# File 3: C:/!Work/interim-bdc-website/src/data/latest-updates\2023-05-19_bdc-marker-paper-announcement\index.mdx
# Metadata: {'path': '/latest-updates/2023-05-19_bdc-marker-paper-announcement', 'date': datetime.date(2023, 5, 19), 'title': 'NHLBI BioData Catalyst® (BDC) Provides Collaborative Cloud Computing Environment to Meet Evolving Researcher Needs', 'subtitle': '', 'tags': ['news', 'publication'], 'seo': {'title': 'NHLBI BioData Catalyst® (BDC) Provides Collaborative Cloud Computing Environment to Meet Evolving Researcher Needs', 'description': '', 'keywords': ['news', 'publication']}, 'file_path': 'C:/!Work/interim-bdc-website/src/data/latest-updates\\2023-05-19_bdc-marker-paper-announcement\\index.mdx'}
# Content preview: This week, the Journal of the American Medical Informatics Association (JAMIA) [published the BDC Co ...
#
# File 4: C:/!Work/interim-bdc-website/src/data/latest-updates\2023-09-11_SCDdatasets\index.mdx
# Metadata: {'path': '/latest-updates/SCDdatasets2023', 'date': datetime.date(2023, 9, 11), 'title': 'BDC supports sickle cell research by hosting key datasets', 'tags': ['blog', 'sickle cell disease'], 'contributor': [{'name': 'Sweta Ladwa', 'image': './SwetaLadwa.jpg', 'description': 'Sweta Ladwa has supported various U.S. Department of Health and Human Services (HHS) entities to address use cases related to scientific data management (including standards, harmonization, and aggregation) and healthcare IT over the past decade. She currently serves as Chief, Scientific Solutions Delivery Branch in the NHLBI Information Technology and Applications Center (ITAC) and is the Data Management Lead for BDC’s data science ecosystem, working with NHLBI-funded investigators, trans-NIH data science program leadership, and BDC developers to ensure data in BDC is optimized for use by the broad scientific research community to advance public health outcomes. She also supports several Trans-NIH initiatives, such as the COVID-19 RECOVER and the NIH Cloud Platform Interoperability (NCPI) programs. Ladwa has an MPH focused in Epidemiology and Biostatistics from The George Washington University and a BS in Biology and Chemistry from Virginia Commonwealth University.'}, {'name': 'Allison Gillaspy', 'image': './AllisonGillaspy.jpg', 'description': 'Allison Gillaspy, Ph.D., is a program officer in the Translational Blood Science and Resources Branch (TRRB) of the Division of Blood Diseases and Resources (DBDR) at NHLBI, part of the National Institutes of Health (NIH). Areas of expertise include high throughput whole genome sequencing, RNAseq/transcriptomics, proteomics, bacterial pathogenesis, microbiome studies and next gen data analysis.\n She is involved with the Cure Sickle Cell Initiative (CureSCi) as the Data Strategy Scientific Program Lead and is Program Director for the NHLBI Biological Specimen and Data Repository (BioLINCC) resource program.'}, {'name': 'Lisbeth A. Welniak', 'image': './LisWelniak.jpg', 'description': 'Lisbeth Welniak, Ph.D., is a program director in the Translational Biology Branch of the Division of Blood Diseases and Resources (DBDR) at NHLBI, part of the National Institutes of Health (NIH). Welniak manages a portfolio of grants, fellowships, and cooperative agreements in the basic and translational scientific research areas of cellular therapies and the consequences of hematopoietic stem cell transplantation as well as basic and clinical immunobiology research in transfusion medicine. Welniak is also a Program Director for the NHLBI Biological Specimen and Data Repository (BioLINCC) resource program and the NHLBI Cure Sickle Cell Initiative.'}], 'seo': {'title': 'BDC supports sickle cell research by hosting key datasets', 'description': '', 'keywords': ['blog', 'sickle cell disease']}, 'file_path': 'C:/!Work/interim-bdc-website/src/data/latest-updates\\2023-09-11_SCDdatasets\\index.mdx'}
# Content preview: [Sickle cell disease](https://www.nhlbi.nih.gov/health/sickle-cell-disease) is an inherited red bloo ...
#
# File 5: C:/!Work/interim-bdc-website/src/data/latest-updates\2023-09-29_BDC-GA4GH-Driver-Project\index.mdx
# Metadata: {'path': '/latest-updates/BDC-GA4GH-Driver-Project', 'date': datetime.date(2023, 9, 28), 'title': 'NHLBI BioData Catalyst® named as a 2023 GA4GH Driver Project', 'subtitle': "Participation in the Driver Project initiative builds upon BDC's previous work in the GA4GH community and formalizes collaboration between the two organizations.", 'tags': ['news', 'GA4GH'], 'seo': {'title': 'NHLBI BioData Catalyst® named as a 2023 GA4GH Driver Project', 'description': '', 'keywords': ['news', 'GA4GH']}, 'file_path': 'C:/!Work/interim-bdc-website/src/data/latest-updates\\2023-09-29_BDC-GA4GH-Driver-Project\\index.mdx'}
# Content preview: <div class="blog-image-section twothirds-width-image blog-image-right">
#   ![An individual standing b ...
#
# File 6: C:/!Work/interim-bdc-website/src/data/latest-updates\2024-02-13-NHLBI-75th-anniversary\index.mdx
# Metadata: {'path': '/latest-updates/NHLBI-75th-anniversary', 'date': datetime.date(2024, 2, 13), 'title': 'NHLBI 75th Anniversary Celebrations Feature BDC', 'subtitle': '', 'tags': ['news', 'NHBLI'], 'seo': {'title': 'NHLBI 75th Anniversary Celebrations Feature BDC', 'description': '', 'keywords': ['news', 'NHBLI']}, 'file_path': 'C:/!Work/interim-bdc-website/src/data/latest-updates\\2024-02-13-NHLBI-75th-anniversary\\index.mdx'}
# Content preview: <div class="blog-image-section half-width-image blog-image-right">
#   ![NHLBI 75th anniversary logo]( ...
#
# File 7: C:/!Work/interim-bdc-website/src/data/latest-updates\2024-04-25_recover\index.mdx
# Metadata: {'path': '/latest-updates/recover_welcome', 'date': datetime.date(2024, 4, 25), 'title': 'Increasing Scientific Research Possibilities by Expanding Access to RECOVER Data', 'subtitle': '', 'tags': ['news', 'NHBLI', 'RECOVER'], 'seo': {'title': 'Increasing Scientific Research Possibilities by Expanding Access to RECOVER Data', 'description': '', 'keywords': ['news', 'NHBLI', 'RECOVER']}, 'file_path': 'C:/!Work/interim-bdc-website/src/data/latest-updates\\2024-04-25_recover\\index.mdx'}
# Content preview: Reproducing published findings and reusing data collected from RECOVER studies have the potential to ...

# %% [markdown]
# ## events

# %%
events_dir = data_dir + "events/"

paths, metadata, contents = get_mdx_files(events_dir)

# Print summary
print(f"Found {len(paths)} MDX files")

# Print details of first few files
for i in range(len(paths)):
    print(f"\nFile {i+1}: {paths[i]}")
    print("Metadata:")
    pprint(metadata[i])
    print("\nContent preview:", contents[i][:100], "...\n")
# Out:
# Parsing MDX files: 100%|██████████| 46/46 [00:00<00:00, 467.24it/s]
# Found 46 MDX files
#
# File 1: C:/!Work/interim-bdc-website/src/data/events\2021-08-11_Community-Hours-Showcase.mdx
# Metadata:
# {'date': datetime.date(2021, 8, 11),
#  'display_date': 'August 11, 2021',
#  'file_path': 'C:/!Work/interim-bdc-website/src/data/events\\2021-08-11_Community-Hours-Showcase.mdx',
#  'forum_post': 'https://bdcatalyst.freshdesk.com/support/discussions/topics/60000406468',
#  'location': '',
#  'path': '/events/2022-08-11/community_hours',
#  'seo': {'description': None,
#          'keywords': ['community hours', 'data access', 'data exploration'],
#          'title': 'NHLBI BioData Catalyst Community Hours: Exploring and '
#                   'Accessing Data'},
#  'tags': ['community hours', 'data access', 'data exploration'],
#  'time': '1:00 - 2:00 pm EDT',
#  'title': 'NHLBI BioData Catalyst Community Hours: Exploring and Accessing '
#           'Data',
#  'url': 'https://bit.ly/3ijOkr9'}
#
# Content preview: Join us on Wednesday, August 11th at 1 pm EDT for an informal, [virtual event](https://bit.ly/3ijOkr ...
#
#
# File 2: C:/!Work/interim-bdc-website/src/data/events\2021-08-25_Community-Hours.mdx
# Metadata:
# {'date': datetime.date(2021, 8, 25),
#  'display_date': 'August 25, 2021',
#  'file_path': 'C:/!Work/interim-bdc-website/src/data/events\\2021-08-25_Community-Hours.mdx',
#  'forum_post': 'https://bdcatalyst.freshdesk.com/support/discussions/topics/60000406481',
#  'location': '',
#  'path': '/events/2022-08-25/community_hours',
#  'seo': {'description': None,
#          'keywords': ['community hours', 'workspaces', 'cloud credits'],
#          'title': 'NHLBI BioData Catalyst Community Hours: A Tour of the '
#                   'Analysis Workspaces'},
#  'tags': ['community hours', 'workspaces', 'cloud credits'],
#  'time': '1:00 - 2:00 pm EDT',
#  'title': 'NHLBI BioData Catalyst Community Hours: A Tour of the Analysis '
#           'Workspaces',
#  'url': 'https://bit.ly/3ArDjuj'}
#
# Content preview: Join us on Wednesday, August 25th at 1 pm EDT for an informal, [virtual event](https://bit.ly/3ArDju ...
#
#
# File 3: C:/!Work/interim-bdc-website/src/data/events\2021-09-15_Community-Hours.mdx
# Metadata:
# {'date': datetime.date(2021, 9, 15),
#  'display_date': 'September 15, 2021',
#  'file_path': 'C:/!Work/interim-bdc-website/src/data/events\\2021-09-15_Community-Hours.mdx',
#  'forum_post': 'https://bdcatalyst.freshdesk.com/support/discussions/topics/60000406524',
#  'location': '',
#  'path': '/events/2021-09-15/community_hours',
#  'seo': {'description': None,
#          'keywords': ['community hours', 'cloud costs'],
#          'title': 'NHLBI BioData Catalyst Community Hours: Cloud Costs'},
#  'tags': ['community hours', 'cloud costs'],
#  'time': '1:00 - 2:00 pm EDT',
#  'title': 'NHLBI BioData Catalyst Community Hours: Cloud Costs',
#  'url': 'https://renci.zoom.us/meeting/register/tJwpd--oqDsjG92aiAgPKQHzNILKgC8gZYVq'}
#
# Content preview: Join us on Wednesday, September 15th from 1:00 pm - 2:00 pm EDT for an informal, [virtual event](htt ...
#
#
# File 4: C:/!Work/interim-bdc-website/src/data/events\2021-10-27_Community-Hours-Showcase.mdx
# Metadata:
# {'date': datetime.date(2021, 10, 27),
#  'display_date': 'October 27, 2021',
#  'file_path': 'C:/!Work/interim-bdc-website/src/data/events\\2021-10-27_Community-Hours-Showcase.mdx',
#  'forum_post': 'https://bdcatalyst.freshdesk.com/support/discussions/topics/60000406677',
#  'location': '',
#  'path': '/events/2021-10-27/community_hours',
#  'seo': {'description': None,
#          'keywords': ['community hours'],
#          'title': 'NHLBI BioData Catalyst Community Hours: First Community '
#                   'Showcase and Meet & greet'},
#  'tags': ['community hours'],
#  'time': '1:00 - 2:00 pm EDT',
#  'title': 'NHLBI BioData Catalyst Community Hours: First Community Showcase '
#           'and Meet & greet',
#  'url': 'https://bit.ly/3AffwxO'}
#
# Content preview: Join us on Wednesday, October 27th from 1:00 pm - 2:00 pm EDT for our, [first BioData Catalyst Commu ...
#
#
# File 5: C:/!Work/interim-bdc-website/src/data/events\2021-11-10_Community-Hours.mdx
# Metadata:
# {'date': datetime.date(2021, 11, 10),
#  'display_date': 'November 10, 2021',
#  'file_path': 'C:/!Work/interim-bdc-website/src/data/events\\2021-11-10_Community-Hours.mdx',
#  'forum_post': 'https://bdcatalyst.freshdesk.com/support/discussions/topics/60000406678',
#  'location': '',
#  'path': '/events/2021-11-10/community_hours',
#  'seo': {'description': None,
#          'keywords': ['community hours'],
#          'title': 'NHLBI BioData Catalyst Community Hours: Workflows with '
#                   'Dockstore'},
#  'tags': ['community hours'],
#  'time': '1:00 - 2:00 pm EDT',
#  'title': 'NHLBI BioData Catalyst Community Hours: Workflows with Dockstore',
#  'url': 'https://bit.ly/3DJez2i'}
#
# Content preview: Join us on Wednesday, November 10th from 1:00 pm - 2:00 pm EDT for an informal, [virtual event](http ...
#
#
# File 6: C:/!Work/interim-bdc-website/src/data/events\2021-12-08_Community-Hours.mdx
# Metadata:
# {'date': datetime.date(2021, 12, 8),
#  'display_date': 'December 8, 2021',
#  'file_path': 'C:/!Work/interim-bdc-website/src/data/events\\2021-12-08_Community-Hours.mdx',
#  'forum_post': 'https://bdcatalyst.freshdesk.com/support/discussions/topics/60000406736',
#  'location': '',
#  'path': '/events/2021-12-08/community_hours',
#  'seo': {'description': None,
#          'keywords': ['community hours', 'ecosystem', 'research'],
#          'title': 'NHLBI BioData Catalyst Community Hours: Ecosystem and '
#                   'Research Highlights'},
#  'tags': ['community hours', 'ecosystem', 'research'],
#  'time': '1:00 - 2:00 pm EDT',
#  'title': 'NHLBI BioData Catalyst Community Hours: Ecosystem and Research '
#           'Highlights',
#  'url': 'https://bit.ly/3H9J1Fi'}
#
# Content preview: Join us on Wednesday, December 8th from 1:00 pm - 2:00 pm EST for our final BioData Catalyst Communi ...
#
#
# File 7: C:/!Work/interim-bdc-website/src/data/events\2022-01-19_Community_Hours.mdx
# Metadata:
# {'date': datetime.date(2022, 1, 19),
#  'display_date': 'January 19, 2022',
#  'file_path': 'C:/!Work/interim-bdc-website/src/data/events\\2022-01-19_Community_Hours.mdx',
#  'forum_post': 'https://bdcatalyst.freshdesk.com/support/discussions/topics/60000406839',
#  'location': '',
#  'path': '/events/2022-01-19/community_hours',
#  'seo': {'description': None,
#          'keywords': ['community hours'],
#          'title': 'NHLBI BioData Catalyst Community Hours: Interactive '
#                   'Analysis with Seven Bridges'},
#  'tags': ['community hours'],
#  'time': '1:00 - 2:00 pm EDT',
#  'title': 'NHLBI BioData Catalyst Community Hours: Interactive Analysis with '
#           'Seven Bridges',
#  'url': 'https://bit.ly/3ocRq3b'}
#
# Content preview: Join us on [Wednesday, January 19th, at 1 pm ET](https://bit.ly/3ocRq3b) to learn how to access and  ...
#
#
# File 8: C:/!Work/interim-bdc-website/src/data/events\2022-02-16_Community-Hours.mdx
# Metadata:
# {'date': datetime.date(2022, 2, 16),
#  'display_date': 'February 16, 2022',
#  'file_path': 'C:/!Work/interim-bdc-website/src/data/events\\2022-02-16_Community-Hours.mdx',
#  'forum_post': 'https://bdcatalyst.freshdesk.com/support/discussions/topics/60000406898',
#  'location': '',
#  'path': '/events/2022-02-16/community_hours',
#  'seo': {'description': None,
#          'keywords': ['community hours'],
#          'title': 'NHLBI BioData Catalyst Community Hours: Reproducible '
#                   'Research Methods'},
#  'tags': ['community hours'],
#  'time': '1:00 - 2:00 pm EDT',
#  'title': 'NHLBI BioData Catalyst Community Hours: Reproducible Research '
#           'Methods',
#  'url': 'https://bit.ly/3nGT8sZ'}
#
# Content preview: Join us on [Wednesday, February 16th at 1 p.m. ET](https://bit.ly/3nGT8sZ) for a session with Dockst ...
#
#
# File 9: C:/!Work/interim-bdc-website/src/data/events\2022-05-16_Workflow_and_Development_Interest_Group.mdx
# Metadata:
# {'date': datetime.date(2022, 5, 16),
#  'display_date': 'May 16, 2022',
#  'file_path': 'C:/!Work/interim-bdc-website/src/data/events\\2022-05-16_Workflow_and_Development_Interest_Group.mdx',
#  'location': 'Zoom (no registration required)',
#  'path': '/events/2022-05-16/interest-groups/workflow-and-development',
#  'registration_required': False,
#  'seo': {'description': None,
#          'keywords': ['interest groups', 'workflow and development'],
#          'title': 'Workflow and Development Interest Group - May'},
#  'tags': ['interest groups', 'workflow and development'],
#  'time': '1:30 - 2:30 p.m. EDT',
#  'title': 'NHLBI BioData Catalyst Workflow and Development Interest Group',
#  'url': 'https://renci.zoom.us/j/99606818968?pwd=S2kwdW5ZbCtabjRYcHRQYWM4NnZkUT09'}
#
# Content preview: *This group meets every third Monday of the month, from 1:30 - 2:30 p.m. ET. Registration is not nec ...
#
#
# File 10: C:/!Work/interim-bdc-website/src/data/events\2022-05-17_Cross-Data_Harmonization_Interest_Group.mdx
# Metadata:
# {'date': datetime.date(2022, 5, 17),
#  'display_date': 'May 17, 2022',
#  'file_path': 'C:/!Work/interim-bdc-website/src/data/events\\2022-05-17_Cross-Data_Harmonization_Interest_Group.mdx',
#  'location': 'Zoom (no registration required)',
#  'path': '/events/2022-05-17/interest-groups/cross-data-harmonization',
#  'seo': {'description': None,
#          'keywords': ['interest groups', 'cross-data harmonization'],
#          'title': 'Cross-Data Harmonization Interest Group - May'},
#  'tags': ['interest groups', 'cross-data harmonization'],
#  'time': '1:00 - 2:00 p.m. EDT',
#  'title': 'NHLBI BioData Catalyst Cross-Data Harmonization Interest Group',
#  'url': 'https://renci.zoom.us/j/92679200774?pwd=VzhoQithMERENzVWakR2Ym5Rd0tydz09'}
#
# Content preview: *This group meets every third Tuesday of the month, from 1:00 - 2:00 p.m. ET. Registration is not ne ...
#
#
# File 11: C:/!Work/interim-bdc-website/src/data/events\2022-05-25_GWAS-TOPMed_Interest_Group.mdx
# Metadata:
# {'date': datetime.date(2022, 5, 25),
#  'display_date': 'May 25, 2022',
#  'file_path': 'C:/!Work/interim-bdc-website/src/data/events\\2022-05-25_GWAS-TOPMed_Interest_Group.mdx',
#  'location': 'Zoom (no registration required)',
#  'path': '/events/2022-05-25/interest-groups/GWAS-TOPMed',
#  'seo': {'description': None,
#          'keywords': ['interest groups', 'GWAS', 'TOPMed'],
#          'title': 'GWAS/TOPMed Interest Group - May'},
#  'tags': ['interest groups', 'GWAS', 'TOPMed'],
#  'time': '11:00 a.m. - 12:00 p.m. EDT',
#  'title': 'NHLBI BioData Catalyst GWAS/TOPMed Interest Group',
#  'url': 'https://renci.zoom.us/j/92679200774?pwd=VzhoQithMERENzVWakR2Ym5Rd0tydz09'}
#
# Content preview: *This group meets every fourth Wednesday of the month, from 11:00 a.m - 12:00 p.m. ET. Registration  ...
#
#
# File 12: C:/!Work/interim-bdc-website/src/data/events\2022-06-21_Cross-Data_Harmonization_Interest_Group.mdx
# Metadata:
# {'date': datetime.date(2022, 6, 21),
#  'display_date': 'June 21, 2022',
#  'file_path': 'C:/!Work/interim-bdc-website/src/data/events\\2022-06-21_Cross-Data_Harmonization_Interest_Group.mdx',
#  'location': 'Zoom (no registration required)',
#  'path': '/events/2022-06-21/interest-groups/cross-data-harmonization',
#  'seo': {'description': None,
#          'keywords': ['interest groups', 'cross-data harmonization'],
#          'title': 'Cross-Data Harmonization Interest Group - June'},
#  'tags': ['interest groups', 'cross-data harmonization'],
#  'time': '1:00 - 2:00 p.m. EDT',
#  'title': 'NHLBI BioData Catalyst Cross-Data Harmonization Interest Group',
#  'url': 'https://renci.zoom.us/j/92679200774?pwd=VzhoQithMERENzVWakR2Ym5Rd0tydz09'}
#
# Content preview: *This group meets every third Tuesday of the month, from 1:00 - 2:00 p.m. ET. Registration is not ne ...
#
#
# File 13: C:/!Work/interim-bdc-website/src/data/events\2022-06-22_Community-Hours.mdx
# Metadata:
# {'date': datetime.date(2022, 6, 22),
#  'display_date': 'June 22, 2022',
#  'file_path': 'C:/!Work/interim-bdc-website/src/data/events\\2022-06-22_Community-Hours.mdx',
#  'forum_post': 'https://bdcatalyst.freshdesk.com/support/discussions/topics/60000407100',
#  'location': 'Zoom',
#  'path': '/events/2022-06-22/community_hours',
#  'registration_required': True,
#  'seo': {'description': None,
#          'title': 'NHLBI BioData Catalyst Community Hours: SAS Studio on '
#                   'BioData Catalyst and COVID-19 Data Harmonization'},
#  'tags': ['community hours'],
#  'time': '1:00 - 2:00 pm EDT',
#  'title': 'NHLBI BioData Catalyst Community Hours: SAS Studio on BioData '
#           'Catalyst and COVID-19 Data Harmonization',
#  'url': 'https://bit.ly/3Mv0YAy'}
#
# Content preview: Join us on **[Wednesday, June 22nd at 1:00 pm ET](https://bit.ly/3Mv0YAy)** for BioData Catalyst Com ...
#
#
# File 14: C:/!Work/interim-bdc-website/src/data/events\2022-06-22_GWAS-TOPMed_Interest_Group.mdx
# Metadata:
# {'date': datetime.date(2022, 6, 22),
#  'display_date': 'June 22, 2022',
#  'file_path': 'C:/!Work/interim-bdc-website/src/data/events\\2022-06-22_GWAS-TOPMed_Interest_Group.mdx',
#  'location': 'Zoom (no registration required)',
#  'path': '/events/2022-06-22/interest-groups/GWAS-TOPMed',
#  'seo': {'description': None,
#          'keywords': ['interest groups', 'GWAS', 'TOPMed'],
#          'title': 'GWAS/TOPMed Interest Group - June'},
#  'tags': ['interest groups', 'GWAS', 'TOPMed'],
#  'time': '11:00 a.m. - 12:00 p.m. EDT',
#  'title': 'NHLBI BioData Catalyst GWAS/TOPMed Interest Group',
#  'url': 'https://renci.zoom.us/j/92679200774?pwd=VzhoQithMERENzVWakR2Ym5Rd0tydz09'}
#
# Content preview: *This group meets every fourth Wednesday of the month, from 11:00 a.m - 12:00 p.m. ET. Registration  ...
#
#
# File 15: C:/!Work/interim-bdc-website/src/data/events\2022-07-19_Cross-Data_Harmonization_Interest_Group.mdx
# Metadata:
# {'date': datetime.date(2022, 7, 19),
#  'display_date': 'July 19, 2022',
#  'file_path': 'C:/!Work/interim-bdc-website/src/data/events\\2022-07-19_Cross-Data_Harmonization_Interest_Group.mdx',
#  'location': 'Zoom (no registration required)',
#  'path': '/events/2022-07-19/interest-groups/cross-data-harmonization',
#  'seo': {'description': None,
#          'keywords': ['interest groups', 'cross-data harmonization'],
#          'title': 'Cross-Data Harmonization Interest Group - July'},
#  'tags': ['interest groups', 'cross-data harmonization'],
#  'time': '1:00 - 2:00 p.m. EDT',
#  'title': 'NHLBI BioData Catalyst Cross-Data Harmonization Interest Group',
#  'url': 'https://renci.zoom.us/j/92679200774?pwd=VzhoQithMERENzVWakR2Ym5Rd0tydz09'}
#
# Content preview: *This group meets every third Tuesday of the month, from 1:00 - 2:00 p.m. ET. Registration is not ne ...
#
#
# File 16: C:/!Work/interim-bdc-website/src/data/events\2022-07-20_Community-Hours.mdx
# Metadata:
# {'date': datetime.date(2022, 7, 20),
#  'display_date': 'July 20, 2022',
#  'file_path': 'C:/!Work/interim-bdc-website/src/data/events\\2022-07-20_Community-Hours.mdx',
#  'forum_post': 'https://bdcatalyst.freshdesk.com/support/discussions/topics/60000407142',
#  'location': 'Zoom',
#  'path': '/events/2022-07-20/community_hours',
#  'registration_required': True,
#  'seo': {'description': None,
#          'title': 'NHLBI BioData Catalyst Community Hours: Sickle Cell Disease '
#                   'Data and Research'},
#  'tags': ['community hours', 'sickle cell disease'],
#  'time': '1:00 - 2:00 pm EDT',
#  'title': 'NHLBI BioData Catalyst Community Hours: Sickle Cell Disease Data '
#           'and Research',
#  'url': 'https://renci.zoom.us/meeting/register/tJcoc-2vrzouGdXVpgP_l5DCXVd1ONu-nNgj'}
#
# Content preview: Join us on **[Wednesday, July 20th at 1:00 pm ET](https://renci.zoom.us/meeting/register/tJcoc-2vrzo ...
#
#
# File 17: C:/!Work/interim-bdc-website/src/data/events\2022-07-27_GWAS-TOPMed_Interest_Group.mdx
# Metadata:
# {'date': datetime.date(2022, 7, 27),
#  'display_date': 'July 27, 2022',
#  'file_path': 'C:/!Work/interim-bdc-website/src/data/events\\2022-07-27_GWAS-TOPMed_Interest_Group.mdx',
#  'location': 'Zoom (no registration required)',
#  'path': '/events/2022-07-27/interest-groups/GWAS-TOPMed',
#  'seo': {'description': None,
#          'keywords': ['interest groups', 'GWAS', 'TOPMed'],
#          'title': 'GWAS/TOPMed Interest Group - July'},
#  'tags': ['interest groups', 'GWAS', 'TOPMed'],
#  'time': '11:00 a.m. - 12:00 p.m. EDT',
#  'title': 'NHLBI BioData Catalyst GWAS/TOPMed Interest Group',
#  'url': 'https://renci.zoom.us/j/92679200774?pwd=VzhoQithMERENzVWakR2Ym5Rd0tydz09'}
#
# Content preview: *This group meets every fourth Wednesday of the month, from 11:00 a.m - 12:00 p.m. ET. Registration  ...
#
#
# File 18: C:/!Work/interim-bdc-website/src/data/events\2022-08-10_Community-Hours.mdx
# Metadata:
# {'date': datetime.date(2022, 8, 10),
#  'display_date': 'August 10, 2022',
#  'file_path': 'C:/!Work/interim-bdc-website/src/data/events\\2022-08-10_Community-Hours.mdx',
#  'forum_post': 'https://bdcatalyst.freshdesk.com/support/discussions/topics/60000407143',
#  'location': 'Zoom',
#  'path': '/events/2022-08-10/community_hours',
#  'registration_required': True,
#  'seo': {'description': None,
#          'title': 'NHLBI BioData Catalyst Community Hours: Performing a GWAS '
#                   'on BioData Catalyst Powered by Terra'},
#  'tags': ['community hours'],
#  'time': '1:00 - 2:00 pm EDT',
#  'title': 'NHLBI BioData Catalyst Community Hours: Performing a GWAS on '
#           'BioData Catalyst Powered by Terra',
#  'url': 'https://renci.zoom.us/meeting/register/tJcqcu6prDMuGdWme-2u9oFUJ284Mogi48JT'}
#
# Content preview: Join us on **[Wednesday, August 10th at 1:00 pm ET](https://renci.zoom.us/meeting/register/tJcqcu6pr ...
#
#
# File 19: C:/!Work/interim-bdc-website/src/data/events\2022-08-16_Cross-Data_Harmonization_Interest_Group.mdx
# Metadata:
# {'date': datetime.date(2022, 8, 16),
#  'display_date': 'August 16th, 2022',
#  'file_path': 'C:/!Work/interim-bdc-website/src/data/events\\2022-08-16_Cross-Data_Harmonization_Interest_Group.mdx',
#  'location': 'Zoom (no registration required)',
#  'path': '/events/2022-08-16/interest-groups/cross-data-harmonization',
#  'seo': {'description': None,
#          'keywords': ['interest groups', 'cross-data harmonization'],
#          'title': 'Cross-Data Harmonization Interest Group - August'},
#  'tags': ['interest groups', 'cross-data harmonization'],
#  'time': '1:00 - 2:00 p.m. EDT',
#  'title': 'NHLBI BioData Catalyst Cross-Data Harmonization Interest Group',
#  'url': 'https://renci.zoom.us/j/92679200774?pwd=VzhoQithMERENzVWakR2Ym5Rd0tydz09'}
#
# Content preview: *This group meets every third Tuesday of the month, from 1:00 - 2:00 p.m. ET. Registration is not ne ...
#
#
# File 20: C:/!Work/interim-bdc-website/src/data/events\2022-08-24_Community-Hours.mdx
# Metadata:
# {'date': datetime.date(2022, 8, 24),
#  'display_date': 'August 24, 2022',
#  'file_path': 'C:/!Work/interim-bdc-website/src/data/events\\2022-08-24_Community-Hours.mdx',
#  'forum_post': 'https://bdcatalyst.freshdesk.com/support/discussions/topics/60000407159',
#  'location': 'Zoom',
#  'path': '/events/2022-08-24/community_hours',
#  'registration_required': True,
#  'seo': {'description': None,
#          'title': 'NHLBI BioData Catalyst Community Hours: Demonstration of '
#                   'SAS on BioData Catalyst'},
#  'tags': ['community hours'],
#  'time': '2:00 - 3:00 pm EDT',
#  'title': 'NHLBI BioData Catalyst Community Hours: Demonstration of SAS on '
#           'BioData Catalyst',
#  'url': 'https://bit.ly/3PnUMvz'}
#
# Content preview: Join us on **[Wednesday, August 24th at 2:00 pm ET](https://bit.ly/3PnUMvz)** for BioData Catalyst C ...
#
#
# File 21: C:/!Work/interim-bdc-website/src/data/events\2022-08-29_Workflow_and_Development_Interest_Group.mdx
# Metadata:
# {'date': datetime.date(2022, 8, 29),
#  'display_date': 'August 29, 2022',
#  'file_path': 'C:/!Work/interim-bdc-website/src/data/events\\2022-08-29_Workflow_and_Development_Interest_Group.mdx',
#  'location': 'Zoom (no registration required)',
#  'path': '/events/2022-08-29/interest-groups/workflow-and-development',
#  'seo': {'description': None,
#          'keywords': ['interest groups', 'workflow and development'],
#          'title': 'Workflow and Development Interest Group - August'},
#  'tags': ['interest groups', 'workflow and development'],
#  'time': '1:30 - 2:30 p.m. EDT',
#  'title': 'NHLBI BioData Catalyst Workflow and Development Interest Group',
#  'url': 'https://renci.zoom.us/j/99606818968?pwd=S2kwdW5ZbCtabjRYcHRQYWM4NnZkUT09'}
#
# Content preview: *This group meets every third Monday of the month, from 1:30 - 2:30 p.m. ET. Registration is not nec ...
#
#
# File 22: C:/!Work/interim-bdc-website/src/data/events\2022-09-28_Community-Hours.mdx
# Metadata:
# {'date': datetime.date(2022, 9, 28),
#  'display_date': 'September 28, 2022',
#  'file_path': 'C:/!Work/interim-bdc-website/src/data/events\\2022-09-28_Community-Hours.mdx',
#  'forum_post': 'https://bdcatalyst.freshdesk.com/support/discussions/topics/60000407297',
#  'location': 'Zoom',
#  'path': '/events/2022-09-28/community_hours',
#  'registration_required': True,
#  'seo': {'description': None,
#          'title': 'NHLBI BioData Catalyst Community Hours: Using BioData '
#                   "Catalyst Powered by PIC-SURE's New Search Interface"},
#  'tags': ['community hours'],
#  'time': '1:00 - 2:00 pm EDT',
#  'title': 'NHLBI BioData Catalyst Community Hours: Using BioData Catalyst '
#           "Powered by PIC-SURE's New Search Interface",
#  'url': 'https://bit.ly/3wmFoIs'}
#
# Content preview: Join us on [Wednesday, September 28th at 1:00 pm ET](https://bit.ly/3wmFoIs) for BioData Catalyst Co ...
#
#
# File 23: C:/!Work/interim-bdc-website/src/data/events\2023-01-25_Community-Hours.mdx
# Metadata:
# {'date': datetime.date(2023, 1, 25),
#  'display_date': 'January 25, 2023',
#  'file_path': 'C:/!Work/interim-bdc-website/src/data/events\\2023-01-25_Community-Hours.mdx',
#  'forum_post': 'https://bdcatalyst.freshdesk.com/support/discussions/topics/60000407342',
#  'location': 'Zoom',
#  'path': '/events/2023-01-25/community_hours',
#  'registration_required': True,
#  'seo': {'description': None,
#          'title': 'NHLBI BioData Catalyst Community Hours: Finding Data'},
#  'tags': ['community hours'],
#  'time': '1:00 - 2:00 pm EST',
#  'title': 'NHLBI BioData Catalyst Community Hours: Finding Data',
#  'url': 'http://bit.ly/BDC-JanCommHours2023'}
#
# Content preview: Join us on [Wednesday, January 25th at 1:00 pm ET](http://bit.ly/BDC-JanCommHours2023) for a session ...
#
#
# File 24: C:/!Work/interim-bdc-website/src/data/events\2023-02-22_Community-Hours.mdx
# Metadata:
# {'date': datetime.date(2023, 2, 22),
#  'display_date': 'February 22, 2023',
#  'file_path': 'C:/!Work/interim-bdc-website/src/data/events\\2023-02-22_Community-Hours.mdx',
#  'forum_post': 'https://bdcatalyst.freshdesk.com/support/discussions/topics/60000407372',
#  'location': 'Zoom',
#  'path': '/events/2023-02-22/community_hours',
#  'registration_required': True,
#  'seo': {'description': None,
#          'title': 'BDC Community Hours: Cloud Workflow Optimization and '
#                   'Researcher Showcase'},
#  'tags': ['community hours'],
#  'time': '1:00 - 2:00 pm EST',
#  'title': 'BDC Community Hours: Cloud Workflow Optimization and Researcher '
#           'Showcase',
#  'url': 'http://bit.ly/BDC-Feb'}
#
# Content preview: Join us on [Wednesday, February 22nd at 1:00 pm ET for Cloud Workflow Optimization and Researcher Sh ...
#
#
# File 25: C:/!Work/interim-bdc-website/src/data/events\2023-03-15_Community-Hours.mdx
# Metadata:
# {'date': datetime.date(2023, 3, 15),
#  'display_date': 'March 15, 2023',
#  'file_path': 'C:/!Work/interim-bdc-website/src/data/events\\2023-03-15_Community-Hours.mdx',
#  'forum_post': 'https://bdcatalyst.freshdesk.com/support/discussions/topics/60000407394',
#  'location': 'Zoom',
#  'path': '/events/2023-03-15/community_hours',
#  'registration_required': True,
#  'seo': {'description': None,
#          'title': 'BDC Community Hours: Citations and Publications'},
#  'tags': ['community hours'],
#  'time': '1:00 - 2:00 pm EST',
#  'title': 'BDC Community Hours: Citations and Publications',
#  'url': 'https://bit.ly/BDC-March'}
#
# Content preview: Join us on [**Wednesday, March 15th at 1 p.m. ET**](https://bit.ly/BDC-March) to learn about best pr ...
#
#
# File 26: C:/!Work/interim-bdc-website/src/data/events\2023-04-26_Community-Hours.mdx
# Metadata:
# {'date': datetime.date(2023, 4, 26),
#  'display_date': 'April 26, 2023',
#  'file_path': 'C:/!Work/interim-bdc-website/src/data/events\\2023-04-26_Community-Hours.mdx',
#  'forum_post': 'https://bdcatalyst.freshdesk.com/support/discussions/topics/60000407425',
#  'location': 'Zoom',
#  'path': '/events/2023-04-26/community_hours',
#  'registration_required': True,
#  'seo': {'description': None,
#          'title': 'BDC Community Hours: What to do While Waiting for Funding'},
#  'tags': ['community hours'],
#  'time': '1:00 - 2:00 pm EST',
#  'title': 'BDC Community Hours: What to do While Waiting for Funding',
#  'url': 'https://bit.ly/BDC-April'}
#
# Content preview: Join us on **[Wednesday, April 26th at 1 p.m. ET](https://bit.ly/BDC-April)** to learn how to explor ...
#
#
# File 27: C:/!Work/interim-bdc-website/src/data/events\2023-05-17_Community-Hours.mdx
# Metadata:
# {'date': datetime.date(2023, 5, 17),
#  'display_date': 'May 17, 2023',
#  'file_path': 'C:/!Work/interim-bdc-website/src/data/events\\2023-05-17_Community-Hours.mdx',
#  'forum_post': 'https://bdcatalyst.freshdesk.com/support/discussions/topics/60000407458',
#  'location': 'Zoom',
#  'path': '/events/2023-05-17/community_hours',
#  'registration_required': True,
#  'seo': {'description': None,
#          'title': 'BDC Community Hours: Newly Published Apps and Workflows'},
#  'tags': ['community hours'],
#  'time': '1:00 - 2:00 pm EST',
#  'title': 'BDC Community Hours: Newly Published Apps and Workflows',
#  'url': 'http://bit.ly/BDC-May'}
#
# Content preview: Join us on [Wednesday, May 17th at 1:00 pm ET](http://bit.ly/BDC-May) to learn about newly published ...
#
#
# File 28: C:/!Work/interim-bdc-website/src/data/events\2023-07-19_Community-Hours.mdx
# Metadata:
# {'date': datetime.date(2023, 7, 19),
#  'display_date': 'July 19, 2023',
#  'file_path': 'C:/!Work/interim-bdc-website/src/data/events\\2023-07-19_Community-Hours.mdx',
#  'forum_post': 'https://bdcatalyst.freshdesk.com/support/discussions/topics/60000407512',
#  'location': 'Zoom',
#  'path': '/events/2023-07-19/community_hours',
#  'registration_required': True,
#  'seo': {'description': None,
#          'title': 'BDC Community Hours: Linking Phenotypic Data to Genomic '
#                   'Data Files'},
#  'tags': ['community hours'],
#  'time': '1:00 - 2:00 pm EST',
#  'title': 'BDC Community Hours: Linking Phenotypic Data to Genomic Data Files',
#  'url': 'https://bit.ly/BDC-July'}
#
# Content preview: Are you a data scientist interested in linking the phenotypic and genomic information of participant ...
#
#
# File 29: C:/!Work/interim-bdc-website/src/data/events\2023-08-23_Community-Hours.mdx
# Metadata:
# {'date': datetime.date(2023, 8, 23),
#  'display_date': 'August 23, 2023',
#  'file_path': 'C:/!Work/interim-bdc-website/src/data/events\\2023-08-23_Community-Hours.mdx',
#  'forum_post': 'https://bdcatalyst.freshdesk.com/support/discussions/topics/60000407545',
#  'location': 'Zoom',
#  'path': '/events/2023-08-23/community_hours',
#  'registration_required': True,
#  'seo': {'description': None,
#          'title': 'BDC Community Hours: Researcher Showcase with TOPMed Fellow '
#                   'Matthew Goodman, PhD'},
#  'tags': ['community hours'],
#  'time': '1:00 - 2:00 pm EST',
#  'title': 'BDC Community Hours: Researcher Showcase with TOPMed Fellow Matthew '
#           'Goodman, PhD',
#  'url': 'https://bit.ly/BDC-August'}
#
# Content preview: Join us on [Wednesday, August 23 at 1 PM ET](https://bit.ly/BDC-August) for a  Showcase featuring [T ...
#
#
# File 30: C:/!Work/interim-bdc-website/src/data/events\2024-02-28_Community-Hours.mdx
# Metadata:
# {'date': datetime.date(2024, 2, 28),
#  'display_date': 'February 28, 2024',
#  'file_path': 'C:/!Work/interim-bdc-website/src/data/events\\2024-02-28_Community-Hours.mdx',
#  'forum_post': 'https://bdcatalyst.freshdesk.com/support/discussions/topics/60000407673',
#  'location': 'Virtual via Zoom',
#  'path': '/events/2024-02-28/community_hours',
#  'registration_required': True,
#  'seo': {'description': None,
#          'title': 'BDC Community Hours: Insights from Genome-Wide Association '
#                   'Studies: Linking Genetics and Imaging'},
#  'tags': ['community hours'],
#  'time': '1:00 - 2:00 pm ET',
#  'title': 'BDC Community Hours: Insights from Genome-Wide Association Studies: '
#           'Linking Genetics and Imaging',
#  'url': 'https://renci.zoom.us/webinar/register/8017053302720/WN_D9w_HA-XRM-zMCMIuCSVPQ'}
#
# Content preview: Dr. Jose Vargas will present on [Wednesday, February 28 1pm ET](https://renci.zoom.us/webinar/regist ...
#
#
# File 31: C:/!Work/interim-bdc-website/src/data/events\2024-03-13_Community-Hours.mdx
# Metadata:
# {'date': datetime.date(2024, 3, 13),
#  'display_date': 'March 13, 2024',
#  'file_path': 'C:/!Work/interim-bdc-website/src/data/events\\2024-03-13_Community-Hours.mdx',
#  'forum_post': 'https://bdcatalyst.freshdesk.com/support/discussions/topics/60000407674',
#  'location': 'Virtual via Zoom',
#  'path': '/events/2024-03-13/community_hours',
#  'registration_required': True,
#  'seo': {'description': None, 'title': 'BDC March Community Hours'},
#  'tags': ['community hours'],
#  'time': '1:00 - 2:00 pm ET',
#  'title': 'BDC March Community Hours',
#  'url': 'https://renci.zoom.us/webinar/register/2117093062319/WN_qWm4svX0T36KwiIAO-mORA'}
#
# Content preview: Join us on Wednesday, March 13 1pm ET for a data update on BDC with Sweta Ladwa, Chief, Scientific S ...
#
#
# File 32: C:/!Work/interim-bdc-website/src/data/events\2024-04-17_Community-Hours.mdx
# Metadata:
# {'date': datetime.date(2024, 4, 17),
#  'display_date': 'Wednesday, April 17, 2024',
#  'file_path': 'C:/!Work/interim-bdc-website/src/data/events\\2024-04-17_Community-Hours.mdx',
#  'forum_post': 'https://bdcatalyst.freshdesk.com/support/discussions/topics/60000407702',
#  'location': 'Zoom',
#  'path': '/events/2024-04-17/community_hours',
#  'registration_required': True,
#  'seo': {'description': None,
#          'title': 'April Community Hours: Teaching with BDC'},
#  'tags': ['community hours'],
#  'time': '1:00 - 2:00 pm EST',
#  'title': 'April Community Hours: Teaching with BDC',
#  'url': 'https://renci.zoom.us/webinar/register/6017103574726/WN_zfMDQHXWQu-vn6XLfprwjw'}
#
# Content preview: Join us on [Wednesday, April 17 1pm EST](https://renci.zoom.us/webinar/register/6017103574726/WN_zfM ...
#
#
# File 33: C:/!Work/interim-bdc-website/src/data/events\2024-05-22_Community-Hours.mdx
# Metadata:
# {'date': datetime.date(2024, 5, 22),
#  'display_date': 'Wednesday, May 22, 2024',
#  'externalEvent': False,
#  'file_path': 'C:/!Work/interim-bdc-website/src/data/events\\2024-05-22_Community-Hours.mdx',
#  'forum_post': 'https://bdcatalyst.freshdesk.com/support/discussions/topics/60000407745',
#  'location': 'Zoom',
#  'path': '/events/2024-05-22/community_hours',
#  'registration_required': True,
#  'seo': {'description': None,
#          'title': 'May Community Hours: Gut microbiota and genetic '
#                   'associations with asthma and among US Hispanic/Latino '
#                   'adults'},
#  'tags': ['community hours'],
#  'time': '1:00 - 2:00 pm EST',
#  'title': 'May Community Hours: Gut microbiota and genetic associations with '
#           'asthma and among US Hispanic/Latino adults',
#  'url': 'https://renci.zoom.us/webinar/register/2517110288834/WN_0Y88g4nPTbatp8iJRENXoA'}
#
# Content preview: Join Dr. Maggie Stanislawski and Dr. Liz Litowski on [Wednesday, May 22 1pm EST](https://renci.zoom. ...
#
#
# File 34: C:/!Work/interim-bdc-website/src/data/events\2024-06-12_Community-Hours.mdx
# Metadata:
# {'date': datetime.date(2024, 6, 12),
#  'display_date': 'Wednesday, June 12, 2024',
#  'externalEvent': False,
#  'file_path': 'C:/!Work/interim-bdc-website/src/data/events\\2024-06-12_Community-Hours.mdx',
#  'forum_post': 'https://bdcatalyst.freshdesk.com/support/discussions/topics/60000407783',
#  'location': 'Zoom',
#  'path': '/events/2024-06-12/community_hours',
#  'registration_required': True,
#  'seo': {'description': None,
#          'title': 'June Community Hours: Discrimination and Carotid '
#                   'Intima-media Thickness: A Multi-Ethnic Study'},
#  'tags': ['community hours'],
#  'time': '1:00 - 2:00 pm EST',
#  'title': 'June Community Hours: Discrimination and Carotid Intima-media '
#           'Thickness: A Multi-Ethnic Study',
#  'url': 'https://renci.zoom.us/webinar/register/2517158800984/WN_3CouMg1wR8Gvyu4jgG7iUw'}
#
# Content preview: Join Assistant Professor Stephanie Cook as she discusses her latest research, [recently published in ...
#
#
# File 35: C:/!Work/interim-bdc-website/src/data/events\2024-07-17_Community-Hours.mdx
# Metadata:
# {'date': datetime.date(2024, 7, 17),
#  'display_date': 'Wednesday, July 17, 2024',
#  'externalEvent': False,
#  'file_path': 'C:/!Work/interim-bdc-website/src/data/events\\2024-07-17_Community-Hours.mdx',
#  'forum_post': 'https://bdcatalyst.freshdesk.com/support/discussions/topics/60000407817',
#  'location': 'Zoom',
#  'path': '/events/2024-07-17/community_hours',
#  'registration_required': True,
#  'seo': {'description': None,
#          'title': 'July Community Hours: Exploration of RECOVER on BDC'},
#  'tags': ['community hours'],
#  'time': '1:00 - 2:00 pm EST',
#  'title': 'July Community Hours: Exploration of RECOVER on BDC',
#  'url': 'https://renci.zoom.us/webinar/register/2817182003893/WN_VdJI6isLRMai95eKbEri6Q'}
#
# Content preview: RECOVER is a first-of-its-kind, patient-centered research initiative to understand, diagnose, and tr ...
#
#
# File 36: C:/!Work/interim-bdc-website/src/data/events\2024-08-21_Community-Hours.mdx
# Metadata:
# {'date': datetime.date(2024, 8, 21),
#  'display_date': 'Wednesday, August 21, 2024',
#  'externalEvent': False,
#  'file_path': 'C:/!Work/interim-bdc-website/src/data/events\\2024-08-21_Community-Hours.mdx',
#  'forum_post': 'https://bdcatalyst.freshdesk.com/support/discussions/topics/60000407843',
#  'location': 'Zoom',
#  'path': '/events/2024-08-21/community_hours',
#  'registration_required': True,
#  'seo': {'description': None,
#          'title': 'August Community Hours: BDC Mid-2024 Data Update'},
#  'tags': ['community hours'],
#  'time': '3:00 - 4:00 pm EST',
#  'title': 'August Community Hours: BDC Mid-2024 Data Update',
#  'url': 'https://renci.zoom.us/webinar/register/3317183108638/WN_SQ8iDYjHS0iHi-Zi15-tgA'}
#
# Content preview: Join Sweta Ladwa as she briefs the BDC Community on the data-related developments to date in 2024, a ...
#
#
# File 37: C:/!Work/interim-bdc-website/src/data/events\2024-09-18_Community-Hours.mdx
# Metadata:
# {'date': datetime.date(2024, 9, 18),
#  'display_date': 'Wednesday, September 18, 2024',
#  'externalEvent': False,
#  'file_path': 'C:/!Work/interim-bdc-website/src/data/events\\2024-09-18_Community-Hours.mdx',
#  'forum_post': 'https://bdcatalyst.freshdesk.com/support/discussions/topics/60000407862',
#  'location': 'Zoom',
#  'path': '/events/2024-09-18/community_hours',
#  'registration_required': True,
#  'seo': {'description': None,
#          'title': 'September Community Hours: Sickle Cell Data on BDC'},
#  'tags': ['community hours', 'sickle cell disease'],
#  'time': '1:00 - 2:00 pm ET',
#  'title': 'September Community Hours: Sickle Cell Data on BDC',
#  'url': 'https://renci.zoom.us/webinar/register/8017241872334/WN_GjMhxs7rQNOyQWZgiygS8w'}
#
# Content preview: Register to hear about NHLBI's sickle cell disease work, the Sickle Cell Disease Implementation Cons ...
#
#
# File 38: C:/!Work/interim-bdc-website/src/data/events\2024-10-23_Community-Hours.mdx
# Metadata:
# {'date': datetime.date(2024, 10, 23),
#  'display_date': 'Wednesday, October 23, 2024',
#  'externalEvent': False,
#  'file_path': 'C:/!Work/interim-bdc-website/src/data/events\\2024-10-23_Community-Hours.mdx',
#  'forum_post': 'https://bdcatalyst.freshdesk.com/support/discussions/forums/60000252439',
#  'location': 'Zoom',
#  'path': '/events/2024-10-23/community_hours',
#  'registration_required': True,
#  'seo': {'description': None,
#          'title': 'October Community Hours: Exploring RECOVER'},
#  'tags': ['community hours', 'RECOVER'],
#  'time': '1:00 - 2:00 pm ET',
#  'title': 'October Community Hours: Exploring RECOVER',
#  'url': 'https://renci.zoom.us/webinar/register/7317267528981/WN_YflU7LdLTPaKDniE5tLEGw'}
#
# Content preview: Join us for this Community Hours where we will be demonstrating how to explore RECOVER using one of  ...
#
#
# File 39: C:/!Work/interim-bdc-website/src/data/events\2024-11-05_BDC-at-ASHG.mdx
# Metadata:
# {'date': datetime.date(2024, 11, 8),
#  'display_date': 'Tuesday, November 5 - Friday, November 8, 2024',
#  'externalEvent': True,
#  'file_path': 'C:/!Work/interim-bdc-website/src/data/events\\2024-11-05_BDC-at-ASHG.mdx',
#  'location': 'Denver, CO',
#  'path': '/events/2024-11-05/BDC-at-ASHG',
#  'registration_required': False,
#  'seo': {'description': None,
#          'title': 'BDC at ASHG (American Society of Human Genetics) Annual '
#                   'Meeting'},
#  'tags': ['ASHG'],
#  'title': 'BDC at ASHG (American Society of Human Genetics) Annual Meeting'}
#
# Content preview: BDC representatives will be attending ASHG 2024, the American Society of Human Genetics Annual Meeti ...
#
#
# File 40: C:/!Work/interim-bdc-website/src/data/events\2024-11-20_Community-Hours.mdx
# Metadata:
# {'date': datetime.date(2024, 11, 20),
#  'display_date': 'Wednesday, November 20, 2024',
#  'externalEvent': False,
#  'file_path': 'C:/!Work/interim-bdc-website/src/data/events\\2024-11-20_Community-Hours.mdx',
#  'forum_post': 'https://bdcatalyst.freshdesk.com/support/discussions/forums/60000252439',
#  'location': 'Zoom',
#  'path': '/events/2024-11-20/community_hours',
#  'registration_required': True,
#  'seo': {'description': None,
#          'title': 'November Community Hours: Professor Susan Redline discusses '
#                   'Sleep Data coming to BDC'},
#  'tags': ['community hours'],
#  'time': '1:00 - 2:00 pm ET',
#  'title': 'November Community Hours: Professor Susan Redline discusses Sleep '
#           'Data coming to BDC',
#  'url': 'https://renci.zoom.us/webinar/register/8217243503385/WN_ewp2GHGGSpa36vwASC1xyQ'}
#
# Content preview: Professor Redline will discuss a recently published paper in SLEEP: The National Sleep Research Reso ...
#
#
# File 41: C:/!Work/interim-bdc-website/src/data/events\2022-06-27_Workflow_and_Development_Interest_Group\index.mdx
# Metadata:
# {'date': datetime.date(2022, 6, 20),
#  'display_date': 'June 27, 2022',
#  'file_path': 'C:/!Work/interim-bdc-website/src/data/events\\2022-06-27_Workflow_and_Development_Interest_Group\\index.mdx',
#  'flyer': './2022-06-27_WORKFLOWDEV_flyer.jpg',
#  'location': 'Zoom (no registration required)',
#  'meeting_info': {'meeting ID': '996 0681 8968', 'passcode': 'BDCatalyst'},
#  'path': '/events/2022-06-20/interest-groups/workflow-and-development',
#  'registration_required': False,
#  'seo': {'description': None,
#          'keywords': ['interest groups', 'workflow and development'],
#          'title': 'Workflow and Development Interest Group - June'},
#  'tags': ['interest groups', 'workflow and development'],
#  'time': '1:30 - 2:30 p.m. EDT',
#  'title': 'NHLBI BioData Catalyst Workflow and Development Interest Group',
#  'url': 'https://renci.zoom.us/j/99606818968?pwd=S2kwdW5ZbCtabjRYcHRQYWM4NnZkUT09'}
#
# Content preview: *This group meets every third Monday of the month, from 1:30 - 2:30 p.m. ET. Registration is not nec ...
#
#
# File 42: C:/!Work/interim-bdc-website/src/data/events\2023-06-21_Community-Hours\index.mdx
# Metadata:
# {'date': datetime.date(2023, 6, 21),
#  'display_date': 'June 21, 2023',
#  'file_path': 'C:/!Work/interim-bdc-website/src/data/events\\2023-06-21_Community-Hours\\index.mdx',
#  'forum_post': 'https://bdcatalyst.freshdesk.com/support/discussions/topics/60000407484',
#  'location': 'Zoom',
#  'path': '/events/2023-06-21/community_hours',
#  'registration_required': True,
#  'seo': {'description': None,
#          'title': 'BDC Researcher Showcase: Bridging the Precision Medicine '
#                   'Gap: Genomic Modeling for Deciphering Congenital Heart '
#                   'Disease (CHD) using Massively Parallel Reporter Assays '
#                   '(MPRAs)'},
#  'speakerImage': './2023-06-21_Community-Hours_Andrew-Blair.png',
#  'tags': ['community hours'],
#  'time': '1:00 - 2:00 pm EST',
#  'title': 'BDC Community Hours: BDC Researcher Showcase',
#  'url': 'https://bit.ly/BDC-June'}
#
# Content preview: ## Andrew Blair | Bridging the Precision Medicine Gap: Genomic Modeling for Deciphering Congenital H ...
#
#
# File 43: C:/!Work/interim-bdc-website/src/data/events\2023-09-13_Community-Hours\index.mdx
# Metadata:
# {'date': datetime.date(2023, 9, 13),
#  'display_date': 'September 13, 2023',
#  'file_path': 'C:/!Work/interim-bdc-website/src/data/events\\2023-09-13_Community-Hours\\index.mdx',
#  'forum_post': 'https://bdcatalyst.freshdesk.com/support/discussions/topics/60000407567',
#  'location': 'Zoom',
#  'path': '/events/2023-09-13/community_hours',
#  'registration_required': True,
#  'seo': {'description': None,
#          'title': 'BDC Community Hours: Sickle Cell Disease Datasets and '
#                   'Research'},
#  'tags': ['community hours', 'sickle cell disease'],
#  'time': '1:00 - 2:00 pm ET',
#  'title': 'BDC Community Hours: Sickle Cell Disease Datasets and Research',
#  'url': 'https://renci.zoom.us/meeting/register/tJcoc-2vrzouGdXVpgP_l5DCXVd1ONu-nNgj'}
#
# Content preview: Join us on [Wednesday, September 13th at 1:00 pm ET](https://renci.zoom.us/meeting/register/tJcoc-2v ...
#
#
# File 44: C:/!Work/interim-bdc-website/src/data/events\2023-11-15_Community-Hours\index.mdx
# Metadata:
# {'date': datetime.date(2023, 11, 15),
#  'display_date': 'November 15, 2023',
#  'file_path': 'C:/!Work/interim-bdc-website/src/data/events\\2023-11-15_Community-Hours\\index.mdx',
#  'forum_post': 'https://bdcatalyst.freshdesk.com/support/discussions/topics/60000407621',
#  'location': 'Zoom',
#  'path': '/events/2023-11-15/community_hours',
#  'registration_required': True,
#  'seo': {'description': None,
#          'title': 'BDC Community Hours: Researching the Genetics of Lung '
#                   'Diseases and Building Custom Workflows on BDC'},
#  'tags': ['community hours'],
#  'time': '1:00 - 2:00 pm ET',
#  'title': 'BDC Community Hours: Researching the Genetics of Lung Diseases and '
#           'Building Custom Workflows on BDC',
#  'url': 'http://bit.ly/BDC-Nov'}
#
# Content preview: Join us on Wednesday, November 15 at 1 PM ET for BDC November Community Hours: Researching the Genet ...
#
#
# File 45: C:/!Work/interim-bdc-website/src/data/events\2023-12-13_Community-Hours\index.mdx
# Metadata:
# {'date': datetime.date(2023, 12, 13),
#  'display_date': 'December 13, 2023',
#  'file_path': 'C:/!Work/interim-bdc-website/src/data/events\\2023-12-13_Community-Hours\\index.mdx',
#  'forum_post': 'https://bdcatalyst.freshdesk.com/support/discussions/topics/60000407631',
#  'location': 'Zoom',
#  'path': '/events/2023-12-13/community_hours',
#  'registration_required': True,
#  'seo': {'description': None,
#          'title': 'BDC Community Hours: Ecosystem and Research Highlights'},
#  'tags': ['community hours'],
#  'time': '1:00 - 2:00 pm ET',
#  'title': 'BDC Community Hours: Ecosystem and Research Highlights',
#  'url': 'https://renci.zoom.us/meeting/register/tJcoc-2vrzouGdXVpgP_l5DCXVd1ONu-nNgj'}
#
# Content preview: Join us on Wednesday, December 13 at 1 PM ET for BDC December Community Hours: Ecosystem and Researc ...
#
#
# File 46: C:/!Work/interim-bdc-website/src/data/events\2024-01-17_Community-Hours\index.mdx
# Metadata:
# {'date': datetime.date(2024, 1, 17),
#  'display_date': 'January 17, 2024',
#  'file_path': 'C:/!Work/interim-bdc-website/src/data/events\\2024-01-17_Community-Hours\\index.mdx',
#  'forum_post': 'https://bdcatalyst.freshdesk.com/support/discussions/topics/60000407644',
#  'location': 'Zoom',
#  'path': '/events/2024-01-17/community_hours',
#  'registration_required': True,
#  'seo': {'description': None, 'title': 'BDC Community Hours: Art of the Start'},
#  'tags': ['community hours'],
#  'time': '2:00 - 3:00 pm EST',
#  'title': 'BDC Community Hours: Art of the Start',
#  'url': 'https://renci.zoom.us/webinar/register/6517025718497/WN_O0SRkPrnREqb5RN-Gz_lQg'}
#
# Content preview: <div class="blog-image-section twothirds-width-image blog-image-right">
#   ![View enlarged image](./2 ...
